# %% [markdown]
# # Task 1

# %%
email = "Amit_ml@gmail.edu"
if email.count("@") == 1:
    split = email.split("@")
    part_1 = split[0]
    part_2 = split[1]
    if part_2.count(".") >= 1:
        part_3 = part_2.split(".")
        domain = part_3[0]
        if email.endswith(".com"):
            domain_type = "Commercial Domain"
        elif email.endswith(".edu"):
            domain_type = "Educational Domain"
        else:
            domain_type = "Other Domain"
        print(f"Username: {part_1}")
        print(f"Domain: {domain}")
        print(f"Domain Type: {domain_type}")
# Out:
# Username: Amit_ml
# Domain: gmail
# Domain Type: Educational Domain

# %% [markdown]
# # Task 2

# %%
encoded_message = "###! !@mocleW EPGTQ !!! 6789"
msg = encoded_message.split("@")[1].split("!!!")[0].strip()

w1 = msg.split(" ")[0]
w2 = msg.split(" ")[1]

w1_rev = "".join(reversed(w1)).capitalize()
w2_clean = w2.replace("E", "")

final_msg = f"{w1_rev} {w2_clean}"
print(final_msg)
# Out:
# Welcom PGTQ
